# %% [markdown]
# **Install**

# %%
# !wget https://www.ks.uiuc.edu/Research/namd/3.0b7/download/231945/NAMD_3.0b7_Linux-x86_64-multicore-CUDA.tar.gz

# %%
# !tar -zxf /content/NAMD_3.0b7_Linux-x86_64-multicore-CUDA.tar.gz

# %%
# a copy from charmm-gui.tgz from my drive to the server

# !cp /content/drive/MyDrive/Test_Prt_lig/charmm-gui.tgz /content/NAMD_3.0b7_Linux-x86_64-multicore-CUDA/

# %%
# unzip

# !tar -zxf /content/NAMD_3.0b7_Linux-x86_64-multicore-CUDA/charmm-gui.tgz -C /content/NAMD_3.0b7_Linux-x86_64-multicore-CUDA/

# %%
# copy /content/NAMD_3.0b7_Linux-x86_64-multicore-CUDA to /content/drive/MyDrive

# !cp -r /content/NAMD_3.0b7_Linux-x86_64-multicore-CUDA /content/drive/MyDrive/

# %% [markdown]
# **Equilibration Step**

# %%
#Equ, Make your input file using charm gui to use it for the two steps.
#step4_equilibration.inp   replace this by your file name
# !/content/NAMD_3.0b7_Linux-x86_64-multicore-CUDA/namd3 +auto-provision /content/NAMD_3.0b7_Linux-x86_64-multicore-CUDA/charmm-gui-1744650878/namd/step4_equilibration.inp > /content/drive/MyDrive/output_test/trial_equ000.log

# %% [markdown]
# **Production Step**

# %%
#Prod
# !/content/NAMD_3.0b7_Linux-x86_64-multicore-CUDA/namd3 +auto-provision /content/drive/MyDrive/NAMD_3.0b7_Linux-x86_64-multicore-CUDA/charmm-gui-1744650878/namd/step5_production.inp > /content/drive/MyDrive/output_test/trial_prod1.log
